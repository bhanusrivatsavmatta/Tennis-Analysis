# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\bhanu\\Data Science Daily\\Tennis Analysis'

# %%
atp_data = pd.read_csv('matches_data_frame.csv')

# %%
atp_data.describe()
# Out:
#           draw_size  tourney_date     match_num      winner_id   winner_seed  \
# count  92298.000000  9.229800e+04  92298.000000   92298.000000  37412.000000
# mean      52.438135  2.002771e+07     37.892089  103223.263050      6.756923
# std       37.634610  8.006136e+04     58.203612    2339.778283      5.994650
# min        4.000000  1.990010e+07      1.000000  100284.000000      1.000000
# 25%       32.000000  1.996022e+07      8.000000  101900.000000      2.000000
# 50%       32.000000  2.002091e+07     20.000000  103033.000000      5.000000
# 75%       56.000000  2.010012e+07     37.000000  104259.000000      8.000000
# max      128.000000  2.017083e+07    319.000000  202382.000000     35.000000
#
#           winner_ht    winner_age   winner_rank  winner_rank_points  \
# count  87574.000000  92201.000000  89303.000000        89303.000000
# mean     185.284457     25.536118     81.925859         1334.962476
# std        6.615031      3.585824    136.413930         1671.968679
# min      160.000000     14.351814      1.000000            1.000000
# 25%      180.000000     22.891170     18.000000          494.000000
# 50%      185.000000     25.322382     46.000000          829.000000
# 75%      190.000000     27.945243     90.000000         1500.000000
# max      208.000000     42.792608   2101.000000        16950.000000
#
#             loser_id      ...          w_bpFaced         l_ace          l_df  \
# count   92298.000000      ...       79400.000000  79400.000000  79400.000000
# mean   103349.497985      ...           5.189912      4.723514      3.513363
# std      3172.259686      ...           4.067147      4.564691      2.631017
# min    100282.000000      ...           0.000000      0.000000      0.000000
# 25%    101889.000000      ...           2.000000      2.000000      2.000000
# 50%    103018.000000      ...           4.000000      4.000000      3.000000
# 75%    104269.000000      ...           7.000000      7.000000      5.000000
# max    207277.000000      ...          34.000000    103.000000     26.000000
#
#              l_svpt       l_1stIn      l_1stWon      l_2ndWon       l_SvGms  \
# count  79400.000000  79400.000000  79400.000000  79400.000000  79400.000000
# mean      80.643438     47.593741     31.556776     15.015264     12.059433
# std       29.494113     19.356080     14.406163      7.260910      4.164653
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       59.000000     34.000000     21.000000     10.000000      9.000000
# 50%       75.000000     44.000000     29.000000     14.000000     11.000000
# 75%       96.000000     58.000000     39.000000     19.000000     15.000000
# max      489.000000    328.000000    284.000000    101.000000     91.000000
#
#           l_bpSaved     l_bpFaced
# count  79400.000000  79400.000000
# mean       4.811637      8.770202
# std        3.271508      4.123164
# min       -6.000000      0.000000
# 25%        2.000000      6.000000
# 50%        4.000000      8.000000
# 75%        7.000000     11.000000
# max       28.000000     35.000000
#
# [8 rows x 35 columns]

# %%
atp_data.head(1)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   1990-360   Casablanca    Clay         32             A      19900305
#
#    match_num  winner_id  winner_seed winner_entry    ...    w_bpFaced l_ace  \
# 0          1     101649          1.0          NaN    ...          NaN   NaN
#
#    l_df l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved l_bpFaced
# 0   NaN    NaN      NaN       NaN       NaN      NaN        NaN       NaN
#
# [1 rows x 49 columns]

# %%
atp_data.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced'],
#       dtype='object')

# %%
select_columns = ['tourney_name','surface','draw_size','tourney_level','tourney_date','winner_seed','winner_ioc','winner_name','winner_age','winner_rank',
                 'loser_seed','loser_name','loser_ioc','loser_rank','loser_age','score','best_of','round','minutes','w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
       'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
       'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
       'l_bpFaced']

# %%
atp_data_condense = atp_data[select_columns]

# %%
atp_data_condense.shape
# Out:
# (92298, 37)

# %% [markdown]
# ###########################################################################################################
#
# restructure data to look at a player level aggregation which shall help us conduct a more profound analysis
# ###########################################################################################################

# %%
atp_data_group = atp_data_condense.groupby(['winner_name','loser_name'])[['winner_seed','loser_seed','minutes','w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
       'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
       'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
       'l_bpFaced']].mean()

# %%
atp_data_group.shape
atp_data_group = atp_data_group.reset_index()
atp_data_group.head(5)
# Out:
#         winner_name         loser_name  winner_seed  loser_seed     minutes  \
# 0  Aaron Krickstein    Alex Antonitsch     5.500000         NaN   84.000000
# 1  Aaron Krickstein        Alex Obrien          NaN         NaN  152.000000
# 2  Aaron Krickstein  Alexander Reichel     5.000000         NaN   67.000000
# 3  Aaron Krickstein   Alexander Volkov     4.500000         5.0  124.600000
# 4  Aaron Krickstein      Amos Mansdorf     9.333333        14.0   94.333333
#
#       w_ace      w_df     w_svpt  w_1stIn   w_1stWon    ...      w_bpFaced  \
# 0  3.500000  2.000000  57.500000     29.0  18.000000    ...       5.000000
# 1  8.000000  4.000000  96.000000     54.0  43.000000    ...      11.000000
# 2  3.000000  1.000000  50.000000     33.0  28.000000    ...       3.000000
# 3  7.200000  2.400000  99.200000     57.4  41.000000    ...       8.400000
# 4  2.333333  1.666667  75.333333     42.0  29.333333    ...       8.666667
#
#    l_ace      l_df      l_svpt    l_1stIn  l_1stWon   l_2ndWon    l_SvGms  \
# 0    4.5  4.000000   71.000000  41.000000      25.0   9.500000   9.500000
# 1    7.5  7.000000  122.500000  70.500000      50.5  18.000000  14.500000
# 2    5.0  7.000000   56.000000  32.000000      16.0  11.000000   8.000000
# 3    8.2  3.200000  105.000000  56.600000      37.0  22.000000  15.000000
# 4    3.0  3.666667   81.333333  50.333333      31.0   9.666667  11.666667
#
#    l_bpSaved  l_bpFaced
# 0        6.0  11.500000
# 1       10.5  15.500000
# 2        3.0   7.000000
# 3        9.4  14.600000
# 4        8.0  13.666667
#
# [5 rows x 23 columns]

# %%
atp_data_group = atp_data_group.fillna(0)

# %%
atp_data_group.describe()
# Out:
#         winner_seed    loser_seed       minutes         w_ace          w_df  \
# count  61795.000000  61795.000000  61795.000000  61795.000000  61795.000000
# mean       2.790849      1.871923     83.815794      5.303228      2.370098
# std        5.060484      4.504635     49.905157      5.016023      2.286214
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000     62.000000      1.333333      0.666667
# 50%        0.000000      0.000000     88.000000      4.000000      2.000000
# 75%        4.000000      0.000000    114.000000      8.000000      3.500000
# max       35.000000     35.000000    987.000000     75.000000     22.000000
#
#              w_svpt       w_1stIn      w_1stWon      w_2ndWon       w_SvGms  \
# count  61795.000000  61795.000000  61795.000000  61795.000000  61795.000000
# mean      65.948354     39.961410     30.017692     14.221571     10.354357
# std       37.540600     23.516494     17.268336      8.500016      5.623087
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       49.500000     29.000000     23.000000     10.000000      8.500000
# 50%       68.000000     41.000000     31.000000     15.000000     11.000000
# 75%       88.000000     53.500000     40.000000     19.000000     14.000000
# max      240.000000    194.000000    148.000000     61.000000     42.000000
#
#            ...          w_bpFaced         l_ace          l_df        l_svpt  \
# count      ...       61795.000000  61795.000000  61795.000000  61795.000000
# mean       ...           4.445865      3.921195      3.042431     68.268090
# std        ...           3.953016      4.218267      2.647273     38.224913
# min        ...           0.000000      0.000000      0.000000      0.000000
# 25%        ...           1.000000      1.000000      1.000000     53.000000
# 50%        ...           4.000000      3.000000      3.000000     71.000000
# 75%        ...           7.000000      6.000000      4.333333     91.000000
# max        ...          30.000000     56.000000     23.000000    253.000000
#
#             l_1stIn      l_1stWon      l_2ndWon       l_SvGms     l_bpSaved  \
# count  61795.000000  61795.000000  61795.000000  61795.000000  61795.000000
# mean      40.294059     26.643881     12.689281     10.196018      4.085781
# std       23.694680     16.613060      8.190906      5.578558      3.254242
# min        0.000000      0.000000      0.000000      0.000000     -1.500000
# 25%       29.000000     17.500000      8.000000      8.000000      2.000000
# 50%       41.000000     27.000000     13.000000     10.500000      4.000000
# 75%       54.000000     36.000000     18.000000     14.000000      6.000000
# max      196.000000    145.000000     66.000000     41.000000     25.000000
#
#           l_bpFaced
# count  61795.000000
# mean       7.460903
# std        4.712333
# min        0.000000
# 25%        5.000000
# 50%        7.750000
# 75%       10.000000
# max       33.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# # Visualization

# %%
sns.distplot(atp_data_group['minutes'])
plt.show()

# %%
atp_data_group['winner_name'][0]
# Out:
# 'Aaron Krickstein'

# %% [markdown]
# For Individual Players

# %%
#For Rafael Nadal
sns.distplot(atp_data_group[(atp_data_group['minutes'].where(atp_data_group['winner_name']=='Rafael Nadal').fillna(0)) > 0 ] ['minutes'])
plt.show()

# %%
#For Roger Federer
sns.distplot(atp_data_group[(atp_data_group['minutes'].where(atp_data_group['winner_name']=='Roger Federer').fillna(0)) > 0 ] ['minutes'])
plt.show()

# %%
#For Novak Djokovic
sns.distplot(atp_data_group[(atp_data_group['minutes'].where(atp_data_group['winner_name']=='Novak Djokovic').fillna(0)) > 0 ] ['minutes'])
plt.show()

# %%
#For Andy Murray
sns.distplot(atp_data_group[(atp_data_group['minutes'].where(atp_data_group['winner_name']=='Andy Murray').fillna(0)) > 0 ] ['minutes'])
plt.show()
